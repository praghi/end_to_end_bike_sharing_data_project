# %% [markdown]
# # Bike Sharing Demand Forecasting Project
# 0) Create virtual environment
# 1) Part 1 - Data Ingestion from Azure Blob Storage to Bronze folder
# 2) Part 2 - Data Transformation and Cleaning in Silver folder, then finally data is stored in Gold folder.
# 3) Create Data Modelling and Visualization using PowerBI
# 4) Leverage ML concepts to build prediction model ( EDA, Feature Selection, Model development, Evaluation, Deployment).
# 5) Build MVP streamlit app and FastAPI (optional) for end users for predictions

# %%
# Check PySpark Version
import pyspark 
print("PySpark Version:", pyspark.__version__)
# Out:
# PySpark Version: 3.4.1

# %%
# Simple Spark Session Test
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %% [markdown]
# #  Bronze Layer Construction
# 1. Data Ingestion from Azure Blob Storage
#
#  a) Import libraries
#  b) Set Connect to Azure Blob Storage API to retieve the files from container
#  c) Validate Files exists in Blob Storage, check sizes and Schema of the files
#  d) Load to bronze folder path

# %%
# import the necessary libraries 

from pyspark.sql import SparkSession
import os
from dotenv import load_dotenv
from azure.identity import ClientSecretCredential 
from azure.storage.blob import BlobServiceClient
from azure.keyvault.secrets import SecretClient 
from pyspark.sql.functions import lit, current_date
import pandas as pd 
import io
import time
from azure.core.exceptions import ResourceNotFoundError
from datetime import datetime
import pyarrow as pa
import pyarrow.parquet as pq
import logging 
import holidays

# %%
load_dotenv()
# Out:
# True

# %%
# Load environment variables
client_id=os.environ["AZURE_CLIENT_ID"]
tenant_id=os.environ["AZURE_TENANT_ID"] 
client_secret=os.environ["AZURE_CNT_SECRET"]
vault_url=os.environ["AZURE_VAULT_URL"]
container_name=os.environ["AZURE_CONTAINER_NAME"]
bronze_folder_path=os.environ["BRONZE_FOLDER_PATH"]
silver_folder_path=os.environ["SILVER_FOLDER_PATH"]
gold_folder_path=os.environ["GOLD_FOLDER_PATH"]
bi_log_folder_path=os.environ["BI_LOG_FOLDER_PATH"]

credentials = ClientSecretCredential(
    tenant_id=tenant_id,
    client_id=client_id,
    client_secret=client_secret 
) 

print("Connection to Azure blob storage successfully.")
# Out:
# Connection to Azure blob storage successfully.

# %%
# Create logs folder if missing and remove verbose logs
logging.getLogger("azure").setLevel(logging.WARNING)
os.makedirs(bi_log_folder_path, exist_ok=True)

# Log file path
log_file = os.path.join(bi_log_folder_path, "bi_pipeline.log")
print(log_file)

# Configure logger
logging.basicConfig(
    filename=log_file,
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO,
    filemode="a"   # append to log file
)

logging.info("🚀 BI Pipeline execution started.")
# Out:
# D:\Python\AUSTRACT_Project\end_to_end_bike_sharing_data_project\business_intelligence\logs\bi_pipeline.log

# %%
# Create blob service client
logging.info("Connecting to Azure Blob Storage...")
try:
    blob_service_client = BlobServiceClient(
    account_url=vault_url,
    credential=credentials    # your ClientSecretCredential  
    )
    container_client = blob_service_client.get_container_client(container_name)
    logging.info("Connected to Azure Blob Storage successfully.")
except Exception as e:
    logging.error(f"Failed to connect to Azure Blob Storage: {e}")
    raise

# %%
def load_validated_csv(blob_name: str) -> pd.DataFrame:
    """
    Validates blob existence and size, then loads CSV into pandas.
    Prevents loading if blob is missing or empty.
    """
    # Step 1 — Validate existence and size
    try:
        blob_client = container_client.get_blob_client(blob_name)
        props = blob_client.get_blob_properties()
    except ResourceNotFoundError:
        raise FileNotFoundError(f"Missing required file: {blob_name}")

    if props.size == 0:
        raise ValueError(f"File '{blob_name}' exists but is EMPTY")

    print(f"{blob_name} validated (size = {props.size} bytes)")

    # Step 2 — Load CSV into memory
    data = blob_client.download_blob().readall()
    df = pd.read_csv(io.BytesIO(data))

    print(f"Loaded {blob_name}: {df.shape[0]} rows, {df.shape[1]} columns")
    return df

# %%
# List of required file
logging.info("Validating required files...")
try:
    bikesharing_df = load_validated_csv("bikesharing.csv")
    dates_df = load_validated_csv("dates.csv")
    logging.info("File validation successful.")
except Exception as e:
    logging.error(f"File validation failed: {e}")
    raise
# Out:
# bikesharing.csv validated (size = 1151577 bytes)
# Loaded bikesharing.csv: 17379 rows, 17 columns
# dates.csv validated (size = 52302 bytes)
# Loaded dates.csv: 1046 rows, 9 columns

# %%
# Check schema of both the files

expected_bikesharing_schema = dict(zip(bikesharing_df.columns, bikesharing_df.dtypes.astype(str)))
print(expected_bikesharing_schema)

expected_dates_schema = dict(zip(dates_df.columns, dates_df.dtypes.astype(str)))
print(expected_dates_schema)
# Out:
# {'index': 'int64', 'date': 'object', 'season': 'int64', 'year': 'int64', 'month': 'int64', 'hour': 'int64', 'holiday': 'int64', 'weekday': 'int64', 'workingday': 'int64', 'weather': 'int64', 'temp': 'float64', 'atemp': 'float64', 'humidity': 'float64', 'windspeed': 'float64', 'casual': 'int64', 'registered': 'int64', 'demand': 'int64'}
# {'date': 'object', 'datekey': 'int64', 'day': 'int64', 'month': 'int64', 'month_name': 'object', 'year': 'int64', 'weekday': 'object', 'weekofyear': 'int64', 'is_weekend': 'int64'}

# %%
def validate_schema(df: pd.DataFrame, expected_schema: dict, file_name: str):
    """
    Validate that the dataframe matches the expected schema:
    - Same columns
    - Same dtypes
    """
    # Check columns match
    df_cols = list(df.columns)
    expected_cols = list(expected_schema.keys())

    if df_cols != expected_cols:
        raise ValueError(
            f"❌ Schema mismatch in {file_name}\n"
            f"Expected columns: {expected_cols}\n"
            f"Found columns:    {df_cols}"
        )

    # Check data types match
    for col, expected_type in expected_schema.items():
        actual_type = str(df[col].dtype)

        if actual_type != expected_type:
            raise ValueError(
                f"❌ Datatype mismatch in {file_name} for column '{col}'\n"
                f"Expected: {expected_type}, Found: {actual_type}"
            )

    print(f"Schema validated successfully for {file_name}")

# %%
# Validate schemas from function
logging.info("Validating schema...") 
try:
    validate_schema(bikesharing_df, expected_bikesharing_schema, "bikesharing.csv")
    validate_schema(dates_df, expected_dates_schema, "dates.csv")
    logging.info("Schema validation successful.")
except Exception as e:
    logging.error(f"Schema validation failed: {e}")
    raise
# Out:
# Schema validated successfully for bikesharing.csv
# Schema validated successfully for dates.csv

# %%
# Add data extraction timestamp column for both dataframes and save to bronze folder

current_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
bikesharing_df["data_extract_ts"] = current_ts
dates_df["data_extract_ts"] = current_ts

# %%
# Review the final dataframes   
display(bikesharing_df.head())
display(dates_df.head())
# Out:
#    index       date  season  year  month  hour  holiday  weekday  workingday  \
# 0      1  1/01/2023       1     0      1     0        0        6           0
# 1      2  1/01/2023       1     0      1     1        0        6           0
# 2      3  1/01/2023       1     0      1     2        0        6           0
# 3      4  1/01/2023       1     0      1     3        0        6           0
# 4      5  1/01/2023       1     0      1     4        0        6           0
#
#    weather  temp   atemp  humidity  windspeed  casual  registered  demand  \
# 0        1  0.24  0.2879      0.81        0.0       3          13      16
# 1        1  0.22  0.2727      0.80        0.0       8          32      40
# 2        1  0.22  0.2727      0.80        0.0       5          27      32
# 3        1  0.24  0.2879      0.75        0.0       3          10      13
# 4        1  0.24  0.2879      0.75        0.0       0           1       1
#
#        data_extract_ts
# 0  2025-11-16 08:20:51
# ...

# %%
# save dataframes as parquet files locally and upload to bronze folder in local directory

def save_parquet_local(df, file_path):
    # Create folder if not exists
    folder = os.path.dirname(file_path)
    os.makedirs(folder, exist_ok=True)
    # Save parquet
    table = pa.Table.from_pandas(df)
    pq.write_table(table, file_path)
    rel_path = os.path.relpath(file_path)
    print(f"Saved to local file directory: {rel_path}")

# %%
logging.info("Saving datasets to Bronze layer...")
try:
    save_parquet_local(bikesharing_df, bronze_folder_path + "/bikesharing.parquet")
    save_parquet_local(dates_df,       bronze_folder_path + "/dates.parquet") 
    logging.info("Datasets saved to Bronze layer successfully.")
except Exception as e:
    logging.error(f"Failed to save datasets to Bronze layer: {e}")
    raise
# Out:
# Saved to local file directory: ..\business_intelligence\data\1.bronze\bikesharing.parquet
# Saved to local file directory: ..\business_intelligence\data\1.bronze\dates.parquet

# %% [markdown]
# # Silver Layer Construction
# 2) Data Transformation and Cleaning

# %%
# Extract and read the parquet file from bronze folder to validate 

df_bikesharing = pd.read_parquet(bronze_folder_path + "/bikesharing.parquet") 
df_dates = pd.read_parquet(bronze_folder_path + "/dates.parquet")

# %% [markdown]
# # Construction dim table from df_bikesharing tbl helpful for analysis

# %%
# First create dim_season tables from bikesharing dataframe 

def season_dim_table(df: pd.DataFrame) -> pd.DataFrame:
    season_dim = df[['season']].drop_duplicates().reset_index(drop=True)
    season_dim['season_key'] = season_dim.index + 1
    season_dim ['season_description'] = season_dim['season'].map({1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Autumn'})
    return season_dim[['season_key', 'season_description']]

# %%
# Check the season dimension table
dim_season_tbl_processed = season_dim_table(df_bikesharing)
dim_season_tbl_processed
# Out:
#    season_key season_description
# 0           1             Winter
# 1           2             Spring
# 2           3             Summer
# 3           4             Autumn

# %%
# Create weather dimension table from bikesharing dataframe

def weather_dim_table(df: pd.DataFrame) -> pd.DataFrame:
    weather_dim = df[['weather']].drop_duplicates().reset_index(drop=True)
    weather_dim['weather_key'] = weather_dim.index + 1
    weather_dim ['weather_description'] = weather_dim['weather'].map({1: 'Clear', 2: 'Mist + Cloudy', 3: 'Light Snow/Rain', 4: 'Heavy Rain/Snow'})
    return weather_dim[['weather_key','weather_description']]

# %%
# Check the season dimension table
dim_weather_tbl_processed = weather_dim_table(df_bikesharing)
dim_weather_tbl_processed
# Out:
#    weather_key weather_description
# 0            1               Clear
# 1            2       Mist + Cloudy
# 2            3     Light Snow/Rain
# 3            4     Heavy Rain/Snow

# %%
def hour_dim_table(df: pd.DataFrame) -> pd.DataFrame:
    # Unique hours from the dataset
    hour_dim = df[['hour']].drop_duplicates().reset_index(drop=True)
    hour_dim['hour_key'] = hour_dim.index
    
    # Hour bin classification
    def assign_hour_bin(h):
        if 0 <= h <= 4:
            return '0-4'
        elif 5 <= h <= 7:
            return '5-7'
        elif 8 <= h <= 17:
            return '8-17'
        elif 18 <= h <= 20:
            return '18-20'
        else:
            return '21-23'

    # Hour description classification
    def assign_hour_description(h):
        if 0 <= h <= 4:
            return 'Late Night'
        elif 5 <= h <= 7:
            return 'Early Morning'
        elif 8 <= h <= 17:
            return 'Office Hours'
        elif 18 <= h <= 20:
            return 'Evening'
        else:
            return 'Night'

    hour_dim['hour_bin'] = hour_dim['hour'].apply(assign_hour_bin)
    hour_dim['hour_description'] = hour_dim['hour'].apply(assign_hour_description)

    return hour_dim[['hour_key', 'hour', 'hour_bin', 'hour_description']]

# %% [markdown]
# # Check the hour dimension table

# %%
dim_hour_tbl_processed = hour_dim_table(df_bikesharing)
dim_hour_tbl_processed
# Out:
#     hour_key  hour hour_bin hour_description
# 0          0     0      0-4       Late Night
# 1          1     1      0-4       Late Night
# 2          2     2      0-4       Late Night
# 3          3     3      0-4       Late Night
# 4          4     4      0-4       Late Night
# 5          5     5      5-7    Early Morning
# 6          6     6      5-7    Early Morning
# 7          7     7      5-7    Early Morning
# 8          8     8     8-17     Office Hours
# 9          9     9     8-17     Office Hours
# 10        10    10     8-17     Office Hours
# 11        11    11     8-17     Office Hours
# 12        12    12     8-17     Office Hours
# 13        13    13     8-17     Office Hours
# 14        14    14     8-17     Office Hours
# 15        15    15     8-17     Office Hours
# 16        16    16     8-17     Office Hours
# 17        17    17     8-17     Office Hours
# 18        18    18    18-20          Evening
# 19        19    19    18-20          Evening
# ...

# %% [markdown]
# # Construct temperature, humidity, and windspeed dimension tables

# %%
def temp_humidity_windspeed_dim_table(df: pd.DataFrame):
    # Temp dimension
    temp_dim = df[['temp']].drop_duplicates().reset_index(drop=True)
    temp_dim['temp_key'] = temp_dim.index + 1
    temp_dim['temp_celsius'] = temp_dim['temp'] * 41

    # Round temperature (IMPORTANT FIX)
    temp_dim['temp_celsius_round'] = temp_dim['temp_celsius'].round().astype(int)

    def assign_temp_bin(c):
        if c <= 9:
            return "0-9°C"
        elif 10 <= c <= 18:
            return "10-18°C"
        elif 19 <= c <= 24:
            return "19-24°C"
        elif 25 <= c <= 30:
            return "25-30°C"
        elif 31 <= c <= 35:
            return "31-35°C"
        else:
            return "36°C+"

    def assign_temp_category(c):
        if c <= 9:
            return "Very Cold"
        elif 10 <= c <= 18:
            return "Cold"
        elif 19 <= c <= 24:
            return "Mild"
        elif 25 <= c <= 30:
            return "Warm"
        elif 31 <= c <= 35:
            return "Hot"
        else:
            return "Very Hot"

    # Apply bins to rounded temp
    temp_dim['temp_bin'] = temp_dim['temp_celsius_round'].apply(assign_temp_bin)
    temp_dim['temp_category'] = temp_dim['temp_celsius_round'].apply(assign_temp_category)

    # Humidity (UCI = 'hum')
    humidity_dim = df[['humidity']].drop_duplicates().reset_index(drop=True)
    humidity_dim['humidity_key'] = humidity_dim.index + 1
    humidity_dim['humidity_percentage'] = (humidity_dim['humidity'] * 100).round(1)

    # Categorization
    def assign_humidity_category(h):
        if h <= 29:
            return "Dry"
        elif 30 <= h <= 59:
            return "Comfortable"
        elif 60 <= h <= 79:
            return "Humid"
        else:
            return "Very Humid"

    def assign_humidity_bin(h):
        if h <= 29:
            return "0-29%"
        elif 30 <= h <= 59:
            return "30-59%"
        elif 60 <= h <= 79:
            return "60-79%"
        else:
            return "80-100%"

    humidity_dim['humidity_bin'] = humidity_dim['humidity_percentage'].apply(assign_humidity_bin)
    humidity_dim['humidity_category'] = humidity_dim['humidity_percentage'].apply(assign_humidity_category)

    # Windspeed
    windspeed_dim = df[['windspeed']].drop_duplicates().reset_index(drop=True)
    windspeed_dim['windspeed_key'] = windspeed_dim.index + 1
    windspeed_dim['windspeed_kmh'] = (windspeed_dim['windspeed'] * 67).round(1)

        # Categorization
    def assign_wind_category(w):
        if w <= 5:
            return "Calm"
        elif 6 <= w <= 20:
            return "Breeze"
        elif 21 <= w <= 39:
            return "Windy"
        elif 40 <= w <= 60:
            return "Strong Wind"
        else:
            return "Stormy"

    def assign_wind_bin(w):
        if w <= 5:
            return "0-5 km/h"
        elif 6 <= w <= 20:
            return "6-20 km/h"
        elif 21 <= w <= 39:
            return "21-39 km/h"
        elif 40 <= w <= 60:
            return "40-60 km/h"
        else:
            return "60 km/h+"

    windspeed_dim['windspeed_bin'] = windspeed_dim['windspeed_kmh'].apply(assign_wind_bin)
    windspeed_dim['windspeed_category'] = windspeed_dim['windspeed_kmh'].apply(assign_wind_category)

    return (
        temp_dim[['temp_key', 'temp', 'temp_celsius', 'temp_celsius_round', 'temp_bin', 'temp_category']],
        humidity_dim[['humidity_key', 'humidity', 'humidity_percentage', 'humidity_bin', 'humidity_category']],
        windspeed_dim[['windspeed_key', 'windspeed', 'windspeed_kmh', 'windspeed_bin', 'windspeed_category']]
    )

# %%
# Check the temp , hum, wind dimension table
dim_temp_tbl_processed, dim_humidity_tbl_processed, dim_windspeed_tbl_processed = temp_humidity_windspeed_dim_table(df_bikesharing)
dim_temp_tbl_processed, dim_humidity_tbl_processed, dim_windspeed_tbl_processed
# Out:
# (    temp_key  temp  temp_celsius  temp_celsius_round temp_bin temp_category
#  0          1  0.24          9.84                  10  10-18°C          Cold
#  1          2  0.22          9.02                   9    0-9°C     Very Cold
#  2          3  0.20          8.20                   8    0-9°C     Very Cold
#  3          4  0.32         13.12                  13  10-18°C          Cold
#  4          5  0.38         15.58                  16  10-18°C          Cold
#  5          6  0.36         14.76                  15  10-18°C          Cold
#  6          7  0.42         17.22                  17  10-18°C          Cold
#  7          8  0.46         18.86                  19  19-24°C          Mild
#  8          9  0.44         18.04                  18  10-18°C          Cold
#  9         10  0.40         16.40                  16  10-18°C          Cold
#  10        11  0.34         13.94                  14  10-18°C          Cold
# ...

# %%
# Additional columns on date dimension table 

def get_dim_dates(df: pd.DataFrame) -> pd.DataFrame:
    us_holidays = holidays.US()

    # Ensure 'date' column is datetime
    df['date'] = pd.to_datetime(df['date'])

    # Day of week category (weekday/weekend)
    df['day_of_week_category'] = df['date'].dt.weekday.apply(
        lambda x: "Weekend" if x in [5, 6] else "Weekday"
    )

    # US holiday flag
    df["Is_public_holiday"] = df['date'].isin(us_holidays).astype(int)

    # Quarter
    df['Quarter'] = df['date'].dt.quarter.map({1: "Q1", 2: "Q2", 3: "Q3", 4: "Q4"})

    # Year-Month (2023-Jan format)
    df['Year_Month'] = df['date'].dt.strftime("%Y-%b")

    return df

# %%
#Get the processed date dimension table
dim_dates_tbl_processed = get_dim_dates(df_dates)

#Check the date dimension table
dim_dates_tbl_processed.dtypes
# Out:
# date                    datetime64[ns]
# datekey                          int64
# day                              int64
# month                            int64
# month_name                      object
# year                             int64
# weekday                         object
# weekofyear                       int64
# is_weekend                       int64
# data_extract_ts                 object
# day_of_week_category            object
# Is_public_holiday                int32
# Quarter                         object
# Year_Month                      object
# dtype: object

# %%
df_bikesharing.columns
# Out:
# Index(['index', 'date', 'season', 'year', 'month', 'hour', 'holiday',
#        'weekday', 'workingday', 'weather', 'temp', 'atemp', 'humidity',
#        'windspeed', 'casual', 'registered', 'demand', 'data_extract_ts'],
#       dtype='object')

# %%
#Check the season value counts 
dim_season_tbl_processed
# Out:
#    season_key season_description
# 0           1             Winter
# 1           2             Spring
# 2           3             Summer
# 3           4             Autumn

# %%
bikesharing_df.dtypes
# Out:
# index                int64
# date                object
# season               int64
# year                 int64
# month                int64
# hour                 int64
# holiday              int64
# weekday              int64
# workingday           int64
# weather              int64
# temp               float64
# atemp              float64
# humidity           float64
# windspeed          float64
# casual               int64
# registered           int64
# demand               int64
# data_extract_ts     object
# dtype: object

# %%
# #Checking fact date issue

bikesharing_check = bikesharing_df.merge(
    dim_temp_tbl_processed[['temp', 'temp_key']],
    on='temp', 
    how='left'
)

bikesharing_check
# Out:
#        index        date  season  year  month  hour  holiday  weekday  \
# 0          1   1/01/2023       1     0      1     0        0        6
# 1          2   1/01/2023       1     0      1     1        0        6
# 2          3   1/01/2023       1     0      1     2        0        6
# 3          4   1/01/2023       1     0      1     3        0        6
# 4          5   1/01/2023       1     0      1     4        0        6
# ...      ...         ...     ...   ...    ...   ...      ...      ...
# 17374  17375  31/12/2024       1     1     12    19        0        1
# 17375  17376  31/12/2024       1     1     12    20        0        1
# 17376  17377  31/12/2024       1     1     12    21        0        1
# 17377  17378  31/12/2024       1     1     12    22        0        1
# 17378  17379  31/12/2024       1     1     12    23        0        1
#
#        workingday  weather  temp   atemp  humidity  windspeed  casual  \
# ...

# %%
# Final create joins between fact and dim tables to get keys   
def get_bikesharing_fact_table(df: pd.DataFrame) -> pd.DataFrame:
   ''' 
   Get bikesharing fact table by merging with dimension tables to get surrogate keys.
   '''
    # Get dimension tables
    # Merge to get keys
   
   fact_df = df.copy()

   fact_df = fact_df.merge(
    dim_temp_tbl_processed[['temp', 'temp_key']],
    on='temp', 
    how='left'
) 
  
     
   fact_df = fact_df.merge(
    dim_humidity_tbl_processed[['humidity', 'humidity_key']],
    on='humidity',
    how='left'
)
  
   fact_df = fact_df.merge(
    dim_windspeed_tbl_processed[['windspeed', 'windspeed_key']]
    ,on='windspeed',
    how='left'  
)
   
   fact_df = fact_df.merge(
    dim_season_tbl_processed[['season_key']],
    left_on='season',
    right_on='season_key',
    how='left'
)
   
   fact_df = fact_df.merge(
     dim_weather_tbl_processed[['weather_key']],
     left_on='weather',
     right_on='weather_key',
     how='left'

    ) 
   
   fact_df = fact_df.merge(
     dim_hour_tbl_processed[['hour' , 'hour_key']],
     on='hour',
     how='left'
    )
   #Ensure 'date' column is datetime
   cols = ['date', 'data_extract_ts']
   for col in cols:
    fact_df[col] = pd.to_datetime(
        fact_df[col], 
        dayfirst=True
    )

   time.sleep(2)  # Small delay to ensure datetime conversion
   fact_df = fact_df.merge(
    dim_dates_tbl_processed[['date', 'datekey']],
    on='date',
    how='left'
 )
   
   # Drop natural columns
   fact_df = fact_df.drop(columns=['temp', 'weekday', 
                              'workingday', 'holiday' , 
                              'atemp', 'humidity','windspeed',
                              'season','weather','hour','date',
                                'year', 'month', 'casual', 'registered'])

   return fact_df[['index', 'temp_key', 'humidity_key', 'windspeed_key', 'season_key',
                   'weather_key', 'hour_key', 'datekey', 'demand', 'data_extract_ts']]

# %%
# Preview bikesharing fact table
bikesharing_fact_tbl_processed = get_bikesharing_fact_table(df_bikesharing)
bikesharing_fact_tbl_processed
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_13880\2597378992.py:53: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   fact_df[col] = pd.to_datetime(
#        index  temp_key  humidity_key  windspeed_key  season_key  weather_key  \
# 0          1         1             1              1           1            1
# 1          2         2             2              1           1            1
# 2          3         2             2              1           1            1
# 3          4         1             3              1           1            1
# 4          5         1             3              1           1            1
# ...      ...       ...           ...            ...         ...          ...
# 17374  17375        13            55              9           1            2
# 17375  17376        13            55              9           1            2
# ...

# %%
# Construct the data for machine learning model 
# The original bikesharing dataset is ml hence replicating the same structure   
bikesharing_ml_processed = pd.read_parquet(bronze_folder_path + "/bikesharing.parquet")

# %%
# Create dictionary and use forloop of dataframes to save in silver folderpath as processed files 

processed_dfs = {
    "bikesharing_fact_tbl_processed": bikesharing_fact_tbl_processed,
    "dim_season_tbl_processed": dim_season_tbl_processed,
    "dim_weather_tbl_processed": dim_weather_tbl_processed,
    "dim_hour_tbl_processed": dim_hour_tbl_processed,
    "dim_temp_tbl_processed": dim_temp_tbl_processed,
    "dim_humidity_tbl_processed": dim_humidity_tbl_processed,
    "dim_windspeed_tbl_processed": dim_windspeed_tbl_processed,
    "dim_dates_tbl_processed": dim_dates_tbl_processed,
    "bikesharing_ml_processed": bikesharing_ml_processed
    
}

# %%
# Create function to save all processed dataframes into silver layer as csv files
def save_to_silver(processed_dfs: dict, silver_folder_path: str):
    """
    Save all processed dataframes into the Silver layer as CSV files.
    """

    # Ensure folder exists
    os.makedirs(silver_folder_path, exist_ok=True)

    for name, df in processed_dfs.items():

        file_path = os.path.join(silver_folder_path, f"{name}.csv")
        silver_path = os.path.relpath(file_path)
        try:
            df.to_csv(file_path, index=False, encoding="utf-8")
            print(f"✅ Saved {name} to Silver layer at {silver_path}")

        except Exception as e:
            print(f"❌ Failed to save {name}: {e}")

# %%
# # Check the saved fact table from silver layer
# df_fact = pd.read_csv(silver_folder_path + "/bikesharing_fact_tbl_processed.csv", encoding="utf-8") 
# df_fact.head()
# Out:
#    index  temp_key  humidity_key  windspeed_key  season_key  weather_key  \
# 0      1         1             1              1           1            1
# 1      2         2             2              1           1            1
# 2      3         2             2              1           1            1
# 3      4         1             3              1           1            1
# 4      5         1             3              1           1            1
#
#    hour_key   datekey  demand      data_extract_ts
# 0         0  20230101      16  2025-11-16 08:20:51
# 1         1  20230101      40  2025-11-16 08:20:51
# 2         2  20230101      32  2025-11-16 08:20:51
# 3         3  20230101      13  2025-11-16 08:20:51
# 4         4  20230101       1  2025-11-16 08:20:51

# %%
# # Check ML table
# df_ml = pd.read_csv(silver_folder_path + "/bikesharing_ml_processed.csv", encoding="utf-8")
# df_ml.head()
# Out:
#    index       date  season  year  month  hour  holiday  weekday  workingday  \
# 0      1  1/01/2023       1     0      1     0        0        6           0
# 1      2  1/01/2023       1     0      1     1        0        6           0
# 2      3  1/01/2023       1     0      1     2        0        6           0
# 3      4  1/01/2023       1     0      1     3        0        6           0
# 4      5  1/01/2023       1     0      1     4        0        6           0
#
#    weather  temp   atemp  humidity  windspeed  casual  registered  demand  \
# 0        1  0.24  0.2879      0.81        0.0       3          13      16
# 1        1  0.22  0.2727      0.80        0.0       8          32      40
# 2        1  0.22  0.2727      0.80        0.0       5          27      32
# 3        1  0.24  0.2879      0.75        0.0       3          10      13
# 4        1  0.24  0.2879      0.75        0.0       0           1       1
#
#        data_extract_ts
# 0  2025-11-16 08:20:51
# ...

# %%
logging.info("Saving datasets to Silver layer...")
try:
    save_to_silver(processed_dfs, silver_folder_path)
    
    logging.info("Datasets saved to Silver layer successfully.")
except Exception as e:
    logging.error(f"Failed to save datasets to Silver layer: {e}")
    raise

# %% [markdown]
# # Constructing Gold Layer
# The gold layer would be simple table and change of name from processed to curated

# %%
# Create list and use forloop of dataframes to save in silver folderpath as processed files 

def promote_silver_to_gold(silver_folder_path, gold_folder_path):
    # Ensure gold folder exists
    os.makedirs(gold_folder_path, exist_ok=True)

    # Loop over every CSV in silver
    for file_name in os.listdir(silver_folder_path):

        if file_name.endswith(".csv"):

            # Build full file paths
            silver_file = os.path.join(silver_folder_path, file_name)

            # Replace "processed" with "curated"
            gold_file_name = file_name.replace("_processed", "_curated")
            gold_file = os.path.join(gold_folder_path, gold_file_name)

            # Read → write
            df = pd.read_csv(silver_file, encoding="utf-8-sig")
            df.to_csv(gold_file, index=False, encoding="utf-8-sig")

            print(f"Promoted to GOLD: {gold_file_name}")

# %%
logging.info("Saving datasets to Gold layer...")
try:
    promote_silver_to_gold(silver_folder_path, gold_folder_path)
    
    logging.info("Datasets saved to Gold layer successfully.")
except Exception as e:
    logging.error(f"✔ Failed to save datasets to Gold layer: {e}")
    raise
# Out:
# ✔ Promoted to GOLD: bikesharing_fact_tbl_curated.csv
# ✔ Promoted to GOLD: bikesharing_ml_curated.csv
# ✔ Promoted to GOLD: dim_dates_tbl_curated.csv
# ✔ Promoted to GOLD: dim_hour_tbl_curated.csv
# ✔ Promoted to GOLD: dim_humidity_tbl_curated.csv
# ✔ Promoted to GOLD: dim_season_tbl_curated.csv
# ✔ Promoted to GOLD: dim_temp_tbl_curated.csv
# ✔ Promoted to GOLD: dim_weather_tbl_curated.csv
# ✔ Promoted to GOLD: dim_windspeed_tbl_curated.csv

# %%
# # Testing the gold layer files  
# df_gold = pd.read_csv(gold_folder_path + "/bikesharing_fact_tbl_curated.csv", encoding="utf-8")
# df_gold.head()
# Out:
#    index  temp_key  humidity_key  windspeed_key  season_key  weather_key  \
# 0      1         1             1              1           1            1
# 1      2         2             2              1           1            1
# 2      3         2             2              1           1            1
# 3      4         1             3              1           1            1
# 4      5         1             3              1           1            1
#
#    hour_key   datekey  demand      data_extract_ts
# 0         0  20230101      16  2025-11-16 08:20:51
# 1         1  20230101      40  2025-11-16 08:20:51
# 2         2  20230101      32  2025-11-16 08:20:51
# 3         3  20230101      13  2025-11-16 08:20:51
# 4         4  20230101       1  2025-11-16 08:20:51
